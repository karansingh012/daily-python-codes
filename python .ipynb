# %%
result = None
print(result)
# Out:
# None

# %%
#  floor division roud figure value deta hai remove decimal
a = 10
b = 20
print(a>20 and a==10)
print(a>20 or b==20)
print(not(a>20)) #ye reverse kr deta hai
# =
# +=
# -=
# *=
# Out:
# False
# True
# True

# %%
vegetables = ['karela','aloo']
print('aloo' in vegetables)
# Out:
# True

# %%
#controle statements 
pie = 3.147
radius = float(input('enter radius = '))
area_of_circle = pie*radius*radius
print(f'Area of circle :{area_of_circle}')
# Out:
# Area of circle :453.16799999999995

# %%
"""
if condition:
    statements
else:
  print()

"""
"""
elif
elif use krte hai hum multiole condition ke liye 
"""
age = int(input("ENter your age: "))
if age > 18:
    print("Eligible for vote:")
elif age <= 0:
    print("invalid age")
"""
 
"""
# Out:
# Eligible for vote:

# %%
num1 = float((input("Enter number 1 =")))
num2 = float((input("Enter number 2 = ")))
choice = input("Enter your choice + - * /")
if choice == '+':
     print(f'Addition : {num1 + num2}')
elif choice == '-':
     print(f'Subtraction : {num1 -num2}')
elif choice == '*':
     print(f'Multiplication : {num1*num2}')
elif choice == '/':
     print(f'Division : {num1/num2}')
else:
     print('invalid choice')
# Out:
# Addition : 24.0

# %%
"""
loops
multiple repeat kr skte hai hum kissi bhi task ko 
1-while loop - until unless condtion is true 
2-for loop  limted time tak kissi statment pr itrate krta rhta hai
"""
"""
while loop 
True 

while condition:
    "code execute
"""
# Out:
# ''

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# """
# for loop 
# [1,2,3,4,5]
# 5 times 
# list tuple dict string

# """
a = [1,2,3,4,5]
for i in a:
    print(i)
#     "infinte loop"
#     while True:
#         print('hI')
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# range.py
"""
range(start,stop,step)
step - 1
step - 100,exclude
step - 1
"""
a = list(range(1,10,1))
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# nested loop 
for i in range(1,3):
    for j in range(3,6):
        print(f'{i},{j}')
# Out:
# 1,3
# 1,4
# 1,5
# 2,3
# 2,4
# 2,5

# %%
#break statemnts 
for num in range(1,10,1):
    print(num)
    if num == 5:
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# continue
for num in range(1,5):
    if num == 3: # for skip
        continue
    print(num)
# Out:
# 1
# 2
# 4

# %%
# pass 
for num in range(1,10):
    if num == 5:
        pass # agr abhi decide. nhi kiya hai ki break krna hai ki pass krna hai toh hum abhi pass likhkr chhod skte hai baad me decide krke dal skta hai 
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
"""
1-10 
even number
"""
for i in range(1,11):
    if(i%2 == 0 ):
        print('even',i)
    else:
        print('odd',i)
# Out:
# odd 1
# even 2
# odd 3
# even 4
# odd 5
# even 6
# odd 7
# even 8
# odd 9
# even 10

# %%
start = int(input('Enter start = '))
stop = int(input('Enter stop ='))
skip = int(input('number you want to skip = '))
for i in range(start,stop):
    if i == skip:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
# 11

# %%
## string and characters
name1 = 'karan'
name2 = "karan"
name3 = '''karan''' #multi line string
name4 = """karan"""# multi line string
print(name1,name2,name3,name4)
# Out:
# karan karan karan karan

# %%
# 1 - immutable
# 2 - index
# 3 - iterable
## indexing me hum ek baar me ek hi charter access kr skte hai
"""
right to left 
-ve to -1

left to right 
+ve 0
"""
language = 'python'
for i in language:
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
"""
len()
space is also count
"""
password = "@karan123"
if len(password)>5:
  print("login sucessfulll")
else:
  print("length is too short or <5")
# Out:
# login sucessfulll

# %%
"""
slicing me hum ek baar me 1 ya 1 de jda charter access kr skte hai 

string[start:stop:step]
start = 0
stop = 3 + 1 , exclusive 3,2 agr hume 3rd charter tak jhana hai toh hume +1 one mtlb 4 pass krna hoga tbhi mai 3rd char tk ja paunga 
step - 1 2 3
"""
text = "this is oython the king of AI"
print(text[1:5:1])
# Out:
# his

# %%
"""
print(text(::)) 
pura char pass kr dega 
print(text[::-1]
"""
number = 10
print(10**10)
# Out:
# 10000000000

# %%
# concatenate
#concatenation
name = "sagar"
ser_name = 100
print('Hi',name+ser_name) # hum sirf string ke hi sth concatenate kr kste hai
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       3 name = "sagar"
#       4 ser_name = 100
# ----> 5 print('Hi',name+ser_name)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#checking membership
# text = "python is the king"
# print("king" in text)
email = "karansinghnaipur@gmail.com"
if('@'in email):
    print("valid email")
else:
    print("in-valid email")
# Out:
# valid email

# %%
str = 'KARANSINGH'# .lower() hum yha bhi lga skte hai 
print(str.lower())
# Out:
# karansingh

# %%
str = input('enter your name =').capitalize()
print(str)
# Out:
# Karan

# %%
# title.py
str = input("enter a sentence = ").title()
print(str)
# Out:
# Karan Singh A Btech Studen T

# %%
#swap cass
str = input('enter a sentence = ').swapcase()
print(str)
# Out:
# AbCd

# %%
## Seaarching and replacing method 
text = "python program"
print(text.find("g")) ## index number bta deta hai
# Out:
# 10

# %%
# replace
text = "python programing"
print(text.replace("python","java"))
# Out:
# java programing

# %%
# spliting and joining method
str = "a,b,c"
print(str.split(","))
# Out:
# ['a', 'b', 'c']

# %%
str = "a,b,c"
s = str.split(",")
print('after spliting',s)
# join(iterable)
result = ",".join(s)
print(result)
# Out:
# after spliting ['a', 'b', 'c']
# a,b,c

# %%
# checking method 
str = "python"
print(str.startswith('p'))
print(str.endswith("n"))
print(str.isalpha())
print(str.isdigit())
print(str.isalnum())
# Out:
# True
# True
# True
# False
# True
